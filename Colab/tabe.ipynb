# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import traceback
import sys
import requests
from bs4 import BeautifulSoup
import abc
import pandas as pd
import os
import re
import time

def Err(TryFunction):
    """
    traceback 기능 전용 함수
    """
    try:
        TryFunction()
    except:
        print(traceback.format_exc(), file=sys.stderr)

class ExcelConvertible(metaclass=abc.ABCMeta):

    @abc.abstractmethod
    def column_names(self):
        pass

def to_excel(convertible, filename):
    """
    엑셀로 변환할 수 있는 객체들을 엑셀 파일로 저장합니다. 저장 경로는 {working directory}/tmp/{filename}입니다.
    :param convertible: ExcelConvertible을 구현한 클래스의 객체 또는 그 리스트
    :type convertible: Union[ExcelConvertible, Iterable[ExcelConvertible]]
    :param filename: 저장할 파일의 이름.
    :type filename: str
    """
    df_dict = {}
    try:
        for x in iter(convertible):
            for col in x.column_names():
                if col in df_dict:
                    df_dict[col].append(x.__dict__[col])
                else:
                    df_dict[col] = [x.__dict__[col]]
    except TypeError:
        df_dict = {col: [convertible.__dict__[col]] for col in convertible.column_names()}

    writer = pd.ExcelWriter(os.path.join('', filename))
    df = pd.DataFrame(data=df_dict)
    df.to_excel(writer, sheet_name='output')
    writer.close()

# HTML String으로 받기
def get_html(url):
    """
    FState = 성공 확인
    Body = HTML Body String
    """
    FState = False
    Body = ''

    def request():
        res = requests.get(url=url)
        nonlocal Body
        nonlocal FState

        FState = res.ok
        Body = res.text

    Err(request)

    return Body, FState

class TabeURL:

    def __init__(self, city, area, page):
        """
        city = 도시 (도쿄, 오사카 etc.)
        area = 지역 분류 코드 (도쿄 기준: 1301, 1302, ... 1331)
        page = 현 타베로그 페이지
        """

        self.city = city
        self.area = area
        self.page = page

    # 일정 url 구조를 자동으로 생성
    def url(self):
        return "https://tabelog.com/kr/{:s}/{:s}/rstLst/{:d}/".format(self.city, self.area, self.page)

class TabelogInfo(ExcelConvertible):

    def __init__(self, name, rating, reviews, detail):

        """
        name = 가게 이름 (str)
        rating = 별점 (float)
        reviews = 평가 개수 (int)
        detail = 가게 정보 (str)
        """

        self.name = name
        self.rating = rating
        self.reviews = reviews
        self.detail = detail

    def column_names(self):
        return ['name', 'rating', 'reviews', 'detail']

def collect_info(area, page):

    url_tokyo = TabeURL(city='tokyo', area=area, page=page)

    body, ok = get_html(url=url_tokyo.url())
    if not ok:
        return False, []

    # start parsing
    soup = BeautifulSoup(body, features="lxml")
    shops = soup.select('.js-rstlist-info')

    info_list = []

    for shop in shops:
        for i in range(1, 21):  # 1부터 20까지 반복
            div_selector = f'div:nth-child({i})'
            name_soup = shop.select_one(f'{div_selector} > div.list-rst__wrap.js-open-new-window > div > div.list-rst__contents > div > div.list-rst__rst-name-wrap > h3 > a')
            if not name_soup:
                continue

            rate_soup = shop.select_one(f'{div_selector} > div.list-rst__wrap.js-open-new-window > div > div.list-rst__contents > div > div.list-rst__rate')

            rating_soup = rate_soup.select_one('span.c-rating__val') if rate_soup else None
            review_soup = rate_soup.select_one('p.list-rst__rvw-count > a > em') if rate_soup else None
            detail_soup = shop.select_one(f'{div_selector} > div.list-rst__wrap.js-open-new-window > div > div.list-rst__contents > div > div.list-rst__rst-name-wrap > div')

            name = name_soup.text
            rating = rating_soup.text if rating_soup else '-1'
            review = review_soup.text if review_soup else '0件'
            detail = detail_soup.text if detail_soup else ''

            def reformat_str(s):
                return str(s).strip()

            name = reformat_str(name)
            try:
                rating = float(reformat_str(rating))
            except:
                rating = -1

            try:
                review = int(reformat_str(review).rstrip("件"))
            except:
                review = 0

            detail = reformat_str(detail)

            info = TabelogInfo(name=name, rating=rating, reviews=review, detail=detail)
            info_list.append(info)

    return True, info_list

restaurants = []
Areas = ['A1301', 'A1302', 'A1303', 'A1304', 'A1305', 'A1306', 'A1307', 'A1308', 'A1309', 'A1310',
         'A1311', 'A1312', 'A1313', 'A1314', 'A1315', 'A1316', 'A1317', 'A1318', 'A1319', 'A1320',
         'A1321', 'A1322', 'A1323', 'A1324', 'A1325', 'A1326', 'A1327', 'A1328', 'A1329', 'A1330']

for area in Areas:
    for page in range(1, 11):  # 페이지 조정
        print(f"Collecting area: {area}, page: {page}")
        success, infos = collect_info(area, page)
        if success:
            print(f"Number of restaurants collected: {len(infos)}")
            restaurants += infos
        time.sleep(0.5)

to_excel(convertible=restaurants, filename='tabelog_tokyo.xlsx')
print("Saved to excel")
# Out:
# Collecting area: A1301, page: 1
# Number of restaurants collected: 20
# Collecting area: A1301, page: 2
# Number of restaurants collected: 20
# Collecting area: A1301, page: 3
# Number of restaurants collected: 20
# Collecting area: A1301, page: 4
# Number of restaurants collected: 20
# Collecting area: A1301, page: 5
# Number of restaurants collected: 20
# Collecting area: A1301, page: 6
# Number of restaurants collected: 20
# Collecting area: A1301, page: 7
# Number of restaurants collected: 20
# Collecting area: A1301, page: 8
# Number of restaurants collected: 20
# Collecting area: A1301, page: 9
# Number of restaurants collected: 20
# Collecting area: A1301, page: 10
# Number of restaurants collected: 20
# Collecting area: A1302, page: 1
# Number of restaurants collected: 20
# Collecting area: A1302, page: 2
# Number of restaurants collected: 20
# Collecting area: A1302, page: 3
# Number of restaurants collected: 20
# Collecting area: A1302, page: 4
# Number of restaurants collected: 20
# Collecting area: A1302, page: 5
# Number of restaurants collected: 20
# Collecting area: A1302, page: 6
# Number of restaurants collected: 20
# Collecting area: A1302, page: 7
# Number of restaurants collected: 20
# Collecting area: A1302, page: 8
# Number of restaurants collected: 20
# Collecting area: A1302, page: 9
# Number of restaurants collected: 20
# Collecting area: A1302, page: 10
# Number of restaurants collected: 20
# Collecting area: A1303, page: 1
# Number of restaurants collected: 20
# Collecting area: A1303, page: 2
# Number of restaurants collected: 20
# Collecting area: A1303, page: 3
# Number of restaurants collected: 20
# Collecting area: A1303, page: 4
# Number of restaurants collected: 20
# Collecting area: A1303, page: 5
# Number of restaurants collected: 20
# Collecting area: A1303, page: 6
# Number of restaurants collected: 20
# Collecting area: A1303, page: 7
# Number of restaurants collected: 20
# Collecting area: A1303, page: 8
# Number of restaurants collected: 20
# Collecting area: A1303, page: 9
# Number of restaurants collected: 20
# Collecting area: A1303, page: 10
# Number of restaurants collected: 20
# Collecting area: A1304, page: 1
# Number of restaurants collected: 20
# Collecting area: A1304, page: 2
# Number of restaurants collected: 20
# Collecting area: A1304, page: 3
# Number of restaurants collected: 20
# Collecting area: A1304, page: 4
# Number of restaurants collected: 20
# Collecting area: A1304, page: 5
# Number of restaurants collected: 20
# Collecting area: A1304, page: 6
# Number of restaurants collected: 20
# Collecting area: A1304, page: 7
# Number of restaurants collected: 20
# Collecting area: A1304, page: 8
# Number of restaurants collected: 20
# Collecting area: A1304, page: 9
# Number of restaurants collected: 20
# Collecting area: A1304, page: 10
# Number of restaurants collected: 20
# Collecting area: A1305, page: 1
# Number of restaurants collected: 20
# Collecting area: A1305, page: 2
# Number of restaurants collected: 20
# Collecting area: A1305, page: 3
# Number of restaurants collected: 20
# Collecting area: A1305, page: 4
# Number of restaurants collected: 20
# Collecting area: A1305, page: 5
# Number of restaurants collected: 20
# Collecting area: A1305, page: 6
# Number of restaurants collected: 20
# Collecting area: A1305, page: 7
# Number of restaurants collected: 20
# Collecting area: A1305, page: 8
# Number of restaurants collected: 20
# Collecting area: A1305, page: 9
# Number of restaurants collected: 20
# Collecting area: A1305, page: 10
# Number of restaurants collected: 20
# Collecting area: A1306, page: 1
# Number of restaurants collected: 20
# Collecting area: A1306, page: 2
# Number of restaurants collected: 20
# Collecting area: A1306, page: 3
# Number of restaurants collected: 20
# Collecting area: A1306, page: 4
# Number of restaurants collected: 20
# Collecting area: A1306, page: 5
# Number of restaurants collected: 20
# Collecting area: A1306, page: 6
# Number of restaurants collected: 20
# Collecting area: A1306, page: 7
# Number of restaurants collected: 20
# Collecting area: A1306, page: 8
# Number of restaurants collected: 20
# Collecting area: A1306, page: 9
# Number of restaurants collected: 20
# Collecting area: A1306, page: 10
# Number of restaurants collected: 20
# Collecting area: A1307, page: 1
# Number of restaurants collected: 20
# Collecting area: A1307, page: 2
# Number of restaurants collected: 20
# Collecting area: A1307, page: 3
# Number of restaurants collected: 20
# Collecting area: A1307, page: 4
# Number of restaurants collected: 20
# Collecting area: A1307, page: 5
# Number of restaurants collected: 20
# Collecting area: A1307, page: 6
# Number of restaurants collected: 20
# Collecting area: A1307, page: 7
# Number of restaurants collected: 20
# Collecting area: A1307, page: 8
# Number of restaurants collected: 20
# Collecting area: A1307, page: 9
# Number of restaurants collected: 20
# Collecting area: A1307, page: 10
# Number of restaurants collected: 20
# Collecting area: A1308, page: 1
# Number of restaurants collected: 20
# Collecting area: A1308, page: 2
# Number of restaurants collected: 20
# Collecting area: A1308, page: 3
# Number of restaurants collected: 20
# Collecting area: A1308, page: 4
# Number of restaurants collected: 20
# Collecting area: A1308, page: 5
# Number of restaurants collected: 20
# Collecting area: A1308, page: 6
# Number of restaurants collected: 20
# Collecting area: A1308, page: 7
# Number of restaurants collected: 20
# Collecting area: A1308, page: 8
# Number of restaurants collected: 20
# Collecting area: A1308, page: 9
# Number of restaurants collected: 20
# Collecting area: A1308, page: 10
# Number of restaurants collected: 20
# Collecting area: A1309, page: 1
# Number of restaurants collected: 20
# Collecting area: A1309, page: 2
# Number of restaurants collected: 20
# Collecting area: A1309, page: 3
# Number of restaurants collected: 20
# Collecting area: A1309, page: 4
# Number of restaurants collected: 20
# Collecting area: A1309, page: 5
# Number of restaurants collected: 20
# Collecting area: A1309, page: 6
# Number of restaurants collected: 20
# Collecting area: A1309, page: 7
# Number of restaurants collected: 20
# Collecting area: A1309, page: 8
# Number of restaurants collected: 20
# Collecting area: A1309, page: 9
# Number of restaurants collected: 20
# Collecting area: A1309, page: 10
# Number of restaurants collected: 20
# Collecting area: A1310, page: 1
# Number of restaurants collected: 20
# Collecting area: A1310, page: 2
# Number of restaurants collected: 20
# Collecting area: A1310, page: 3
# Number of restaurants collected: 20
# Collecting area: A1310, page: 4
# Number of restaurants collected: 20
# Collecting area: A1310, page: 5
# Number of restaurants collected: 20
# Collecting area: A1310, page: 6
# Number of restaurants collected: 20
# Collecting area: A1310, page: 7
# Number of restaurants collected: 20
# Collecting area: A1310, page: 8
# Number of restaurants collected: 20
# Collecting area: A1310, page: 9
# Number of restaurants collected: 20
# Collecting area: A1310, page: 10
# Number of restaurants collected: 20
# Collecting area: A1311, page: 1
# Number of restaurants collected: 20
# Collecting area: A1311, page: 2
# Number of restaurants collected: 20
# Collecting area: A1311, page: 3
# Number of restaurants collected: 20
# Collecting area: A1311, page: 4
# Number of restaurants collected: 20
# Collecting area: A1311, page: 5
# Number of restaurants collected: 20
# Collecting area: A1311, page: 6
# Number of restaurants collected: 20
# Collecting area: A1311, page: 7
# Number of restaurants collected: 20
# Collecting area: A1311, page: 8
# Number of restaurants collected: 20
# Collecting area: A1311, page: 9
# Number of restaurants collected: 20
# Collecting area: A1311, page: 10
# Number of restaurants collected: 20
# Collecting area: A1312, page: 1
# Number of restaurants collected: 20
# Collecting area: A1312, page: 2
# Number of restaurants collected: 20
# Collecting area: A1312, page: 3
# Number of restaurants collected: 20
# Collecting area: A1312, page: 4
# Number of restaurants collected: 20
# Collecting area: A1312, page: 5
# Number of restaurants collected: 20
# Collecting area: A1312, page: 6
# Number of restaurants collected: 20
# Collecting area: A1312, page: 7
# Number of restaurants collected: 20
# Collecting area: A1312, page: 8
# Number of restaurants collected: 20
# Collecting area: A1312, page: 9
# Number of restaurants collected: 20
# Collecting area: A1312, page: 10
# Number of restaurants collected: 20
# Collecting area: A1313, page: 1
# Number of restaurants collected: 20
# Collecting area: A1313, page: 2
# Number of restaurants collected: 20
# Collecting area: A1313, page: 3
# Number of restaurants collected: 20
# Collecting area: A1313, page: 4
# Number of restaurants collected: 20
# Collecting area: A1313, page: 5
# Number of restaurants collected: 20
# Collecting area: A1313, page: 6
# Number of restaurants collected: 20
# Collecting area: A1313, page: 7
# Number of restaurants collected: 20
# Collecting area: A1313, page: 8
# Number of restaurants collected: 20
# Collecting area: A1313, page: 9
# Number of restaurants collected: 20
# Collecting area: A1313, page: 10
# Number of restaurants collected: 20
# Collecting area: A1314, page: 1
# Number of restaurants collected: 20
# Collecting area: A1314, page: 2
# Number of restaurants collected: 20
# Collecting area: A1314, page: 3
# Number of restaurants collected: 20
# Collecting area: A1314, page: 4
# Number of restaurants collected: 20
# Collecting area: A1314, page: 5
# Number of restaurants collected: 20
# Collecting area: A1314, page: 6
# Number of restaurants collected: 20
# Collecting area: A1314, page: 7
# Number of restaurants collected: 20
# Collecting area: A1314, page: 8
# Number of restaurants collected: 20
# Collecting area: A1314, page: 9
# Number of restaurants collected: 20
# Collecting area: A1314, page: 10
# Number of restaurants collected: 20
# Collecting area: A1315, page: 1
# Number of restaurants collected: 20
# Collecting area: A1315, page: 2
# Number of restaurants collected: 20
# Collecting area: A1315, page: 3
# Number of restaurants collected: 20
# Collecting area: A1315, page: 4
# Number of restaurants collected: 20
# Collecting area: A1315, page: 5
# Number of restaurants collected: 20
# Collecting area: A1315, page: 6
# Number of restaurants collected: 20
# Collecting area: A1315, page: 7
# Number of restaurants collected: 20
# Collecting area: A1315, page: 8
# Number of restaurants collected: 20
# Collecting area: A1315, page: 9
# Number of restaurants collected: 20
# Collecting area: A1315, page: 10
# Number of restaurants collected: 20
# Collecting area: A1316, page: 1
# Number of restaurants collected: 20
# Collecting area: A1316, page: 2
# Number of restaurants collected: 20
# Collecting area: A1316, page: 3
# Number of restaurants collected: 20
# Collecting area: A1316, page: 4
# Number of restaurants collected: 20
# Collecting area: A1316, page: 5
# Number of restaurants collected: 20
# Collecting area: A1316, page: 6
# Number of restaurants collected: 20
# Collecting area: A1316, page: 7
# Number of restaurants collected: 20
# Collecting area: A1316, page: 8
# Number of restaurants collected: 20
# Collecting area: A1316, page: 9
# Number of restaurants collected: 20
# Collecting area: A1316, page: 10
# Number of restaurants collected: 20
# Collecting area: A1317, page: 1
# Number of restaurants collected: 20
# Collecting area: A1317, page: 2
# Number of restaurants collected: 20
# Collecting area: A1317, page: 3
# Number of restaurants collected: 20
# Collecting area: A1317, page: 4
# Number of restaurants collected: 20
# Collecting area: A1317, page: 5
# Number of restaurants collected: 20
# Collecting area: A1317, page: 6
# Number of restaurants collected: 20
# Collecting area: A1317, page: 7
# Number of restaurants collected: 20
# Collecting area: A1317, page: 8
# Number of restaurants collected: 20
# Collecting area: A1317, page: 9
# Number of restaurants collected: 20
# Collecting area: A1317, page: 10
# Number of restaurants collected: 20
# Collecting area: A1318, page: 1
# Number of restaurants collected: 20
# Collecting area: A1318, page: 2
# Number of restaurants collected: 20
# Collecting area: A1318, page: 3
# Number of restaurants collected: 20
# Collecting area: A1318, page: 4
# Number of restaurants collected: 20
# Collecting area: A1318, page: 5
# Number of restaurants collected: 20
# Collecting area: A1318, page: 6
# Number of restaurants collected: 20
# Collecting area: A1318, page: 7
# Number of restaurants collected: 20
# Collecting area: A1318, page: 8
# Number of restaurants collected: 20
# Collecting area: A1318, page: 9
# Number of restaurants collected: 20
# Collecting area: A1318, page: 10
# Number of restaurants collected: 20
# Collecting area: A1319, page: 1
# Number of restaurants collected: 20
# Collecting area: A1319, page: 2
# Number of restaurants collected: 20
# Collecting area: A1319, page: 3
# Number of restaurants collected: 20
# Collecting area: A1319, page: 4
# Number of restaurants collected: 20
# Collecting area: A1319, page: 5
# Number of restaurants collected: 20
# Collecting area: A1319, page: 6
# Number of restaurants collected: 20
# Collecting area: A1319, page: 7
# Number of restaurants collected: 20
# Collecting area: A1319, page: 8
# Number of restaurants collected: 20
# Collecting area: A1319, page: 9
# Number of restaurants collected: 20
# Collecting area: A1319, page: 10
# Number of restaurants collected: 20
# Collecting area: A1320, page: 1
# Number of restaurants collected: 20
# Collecting area: A1320, page: 2
# Number of restaurants collected: 20
# Collecting area: A1320, page: 3
# Number of restaurants collected: 20
# Collecting area: A1320, page: 4
# Number of restaurants collected: 20
# Collecting area: A1320, page: 5
# Number of restaurants collected: 20
# Collecting area: A1320, page: 6
# Number of restaurants collected: 20
# Collecting area: A1320, page: 7
# Number of restaurants collected: 20
# Collecting area: A1320, page: 8
# Number of restaurants collected: 20
# Collecting area: A1320, page: 9
# Number of restaurants collected: 20
# Collecting area: A1320, page: 10
# Number of restaurants collected: 20
# Collecting area: A1321, page: 1
# Number of restaurants collected: 20
# Collecting area: A1321, page: 2
# Number of restaurants collected: 20
# Collecting area: A1321, page: 3
# Number of restaurants collected: 20
# Collecting area: A1321, page: 4
# Number of restaurants collected: 20
# Collecting area: A1321, page: 5
# Number of restaurants collected: 20
# Collecting area: A1321, page: 6
# Number of restaurants collected: 20
# Collecting area: A1321, page: 7
# Number of restaurants collected: 20
# Collecting area: A1321, page: 8
# Number of restaurants collected: 20
# Collecting area: A1321, page: 9
# Number of restaurants collected: 20
# Collecting area: A1321, page: 10
# Number of restaurants collected: 20
# Collecting area: A1322, page: 1
# Number of restaurants collected: 20
# Collecting area: A1322, page: 2
# Number of restaurants collected: 20
# Collecting area: A1322, page: 3
# Number of restaurants collected: 20
# Collecting area: A1322, page: 4
# Number of restaurants collected: 20
# Collecting area: A1322, page: 5
# Number of restaurants collected: 20
# Collecting area: A1322, page: 6
# Number of restaurants collected: 20
# Collecting area: A1322, page: 7
# Number of restaurants collected: 20
# Collecting area: A1322, page: 8
# Number of restaurants collected: 20
# Collecting area: A1322, page: 9
# Number of restaurants collected: 20
# Collecting area: A1322, page: 10
# Number of restaurants collected: 20
# Collecting area: A1323, page: 1
# Number of restaurants collected: 20
# Collecting area: A1323, page: 2
# Number of restaurants collected: 20
# Collecting area: A1323, page: 3
# Number of restaurants collected: 20
# Collecting area: A1323, page: 4
# Number of restaurants collected: 20
# Collecting area: A1323, page: 5
# Number of restaurants collected: 20
# Collecting area: A1323, page: 6
# Number of restaurants collected: 20
# Collecting area: A1323, page: 7
# Number of restaurants collected: 20
# Collecting area: A1323, page: 8
# Number of restaurants collected: 20
# Collecting area: A1323, page: 9
# Number of restaurants collected: 20
# Collecting area: A1323, page: 10
# Number of restaurants collected: 20
# Collecting area: A1324, page: 1
# Number of restaurants collected: 20
# Collecting area: A1324, page: 2
# Number of restaurants collected: 20
# Collecting area: A1324, page: 3
# Number of restaurants collected: 20
# Collecting area: A1324, page: 4
# Number of restaurants collected: 20
# Collecting area: A1324, page: 5
# Number of restaurants collected: 20
# Collecting area: A1324, page: 6
# Number of restaurants collected: 20
# Collecting area: A1324, page: 7
# Number of restaurants collected: 20
# Collecting area: A1324, page: 8
# Number of restaurants collected: 20
# Collecting area: A1324, page: 9
# Number of restaurants collected: 20
# Collecting area: A1324, page: 10
# Number of restaurants collected: 20
# Collecting area: A1325, page: 1
# Number of restaurants collected: 20
# Collecting area: A1325, page: 2
# Number of restaurants collected: 20
# Collecting area: A1325, page: 3
# Number of restaurants collected: 20
# Collecting area: A1325, page: 4
# Number of restaurants collected: 20
# Collecting area: A1325, page: 5
# Number of restaurants collected: 20
# Collecting area: A1325, page: 6
# Number of restaurants collected: 20
# Collecting area: A1325, page: 7
# Number of restaurants collected: 20
# Collecting area: A1325, page: 8
# Number of restaurants collected: 20
# Collecting area: A1325, page: 9
# Number of restaurants collected: 20
# Collecting area: A1325, page: 10
# Number of restaurants collected: 20
# Collecting area: A1326, page: 1
# Number of restaurants collected: 20
# Collecting area: A1326, page: 2
# Number of restaurants collected: 20
# Collecting area: A1326, page: 3
# Number of restaurants collected: 20
# Collecting area: A1326, page: 4
# Number of restaurants collected: 20
# Collecting area: A1326, page: 5
# Number of restaurants collected: 20
# Collecting area: A1326, page: 6
# Number of restaurants collected: 20
# Collecting area: A1326, page: 7
# Number of restaurants collected: 20
# Collecting area: A1326, page: 8
# Number of restaurants collected: 20
# Collecting area: A1326, page: 9
# Number of restaurants collected: 20
# Collecting area: A1326, page: 10
# Number of restaurants collected: 20
# Collecting area: A1327, page: 1
# Number of restaurants collected: 20
# Collecting area: A1327, page: 2
# Number of restaurants collected: 20
# Collecting area: A1327, page: 3
# Number of restaurants collected: 20
# Collecting area: A1327, page: 4
# Number of restaurants collected: 20
# Collecting area: A1327, page: 5
# Number of restaurants collected: 20
# Collecting area: A1327, page: 6
# Number of restaurants collected: 20
# Collecting area: A1327, page: 7
# Number of restaurants collected: 20
# Collecting area: A1327, page: 8
# Number of restaurants collected: 20
# Collecting area: A1327, page: 9
# Number of restaurants collected: 20
# Collecting area: A1327, page: 10
# Number of restaurants collected: 20
# Collecting area: A1328, page: 1
# Number of restaurants collected: 20
# Collecting area: A1328, page: 2
# Number of restaurants collected: 20
# Collecting area: A1328, page: 3
# Number of restaurants collected: 20
# Collecting area: A1328, page: 4
# Number of restaurants collected: 20
# Collecting area: A1328, page: 5
# Number of restaurants collected: 20
# Collecting area: A1328, page: 6
# Number of restaurants collected: 20
# Collecting area: A1328, page: 7
# Number of restaurants collected: 20
# Collecting area: A1328, page: 8
# Number of restaurants collected: 20
# Collecting area: A1328, page: 9
# Number of restaurants collected: 20
# Collecting area: A1328, page: 10
# Number of restaurants collected: 20
# Collecting area: A1329, page: 1
# Number of restaurants collected: 20
# Collecting area: A1329, page: 2
# Number of restaurants collected: 20
# Collecting area: A1329, page: 3
# Number of restaurants collected: 20
# Collecting area: A1329, page: 4
# Number of restaurants collected: 20
# Collecting area: A1329, page: 5
# Number of restaurants collected: 20
# Collecting area: A1329, page: 6
# Number of restaurants collected: 20
# Collecting area: A1329, page: 7
# Number of restaurants collected: 20
# Collecting area: A1329, page: 8
# Number of restaurants collected: 20
# Collecting area: A1329, page: 9
# Number of restaurants collected: 20
# Collecting area: A1329, page: 10
# Number of restaurants collected: 20
# Collecting area: A1330, page: 1
# Number of restaurants collected: 20
# Collecting area: A1330, page: 2
# Number of restaurants collected: 20
# Collecting area: A1330, page: 3
# Number of restaurants collected: 20
# Collecting area: A1330, page: 4
# Number of restaurants collected: 20
# Collecting area: A1330, page: 5
# Number of restaurants collected: 20
# Collecting area: A1330, page: 6
# Number of restaurants collected: 20
# Collecting area: A1330, page: 7
# Number of restaurants collected: 20
# Collecting area: A1330, page: 8
# Number of restaurants collected: 20
# Collecting area: A1330, page: 9
# Number of restaurants collected: 20
# Collecting area: A1330, page: 10
# Number of restaurants collected: 20
# Saved to excel
